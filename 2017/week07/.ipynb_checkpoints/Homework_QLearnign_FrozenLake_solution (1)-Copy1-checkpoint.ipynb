# %% [markdown]
# # Q Learning
#
# $Q_{s,a} = (1-\alpha).Q_{s,a} + \alpha \left( R_{s,a} + \gamma . max(Q_{s',a'})\right)$

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import gym
import numpy as np
from gym.envs.registration import register
from gym import wrappers
import shutil

# %%
# register(
#     id='FrozenLakeNotSlippery-v0',
#     entry_point='gym.envs.toy_text:FrozenLakeEnv',
#     kwargs={'map_name' : '4x4', 'is_slippery': False},
#     max_episode_steps=100,
#     reward_threshold=0.78, # optimum = .8196
# )

# env = gym.make('FrozenLakeNotSlippery-v0')

# %%
env = gym.make('FrozenLake-v0')
shutil.rmtree('/tmp/FrozenLake_01') 
env = wrappers.Monitor(env, '/tmp/FrozenLake_01')
# Out:
# [2017-10-14 19:33:29,413] Making new env: FrozenLake-v0
# [2017-10-14 19:33:29,734] Creating monitor directory /tmp/FrozenLake_01

# %%
Q= np.zeros((env.observation_space.n, env.action_space.n)) #16x4
alpha=0.1
beta=0.1
gamma=0.95
num_episodes = 1000
reward_list=[]
for i in range(num_episodes):
    s = env.reset();
    done=False
    while done==False:
        if np.random.rand() < beta:
            a = env.action_space.sample()
        else:
            a = np.argmax(Q[s,:] )
        s_next,reward,done,info = env.step(a)
        if done:#reaching goal or falling into a hole
            if reward:
                beta=beta*0.99
            else:
                r=-1
        else:#reaching maximum step
            r = 0.0
        Q[s,a]= (1-alpha)*Q[s,a] + alpha*( r + gamma*np.max(Q[s_next,:]) )
        if done == True:
            break
        s=s_next
    reward_list.append(reward)
                                        
plt.plot(np.convolve(np.ones(100),reward_list,"valid"))
# Out:
# [2017-10-14 19:33:29,796] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000000.json
# [2017-10-14 19:33:29,802] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000001.json
# [2017-10-14 19:33:29,812] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000008.json
# [2017-10-14 19:33:29,832] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000027.json
# [2017-10-14 19:33:29,882] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000064.json
# [2017-10-14 19:33:29,934] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000125.json
# [2017-10-14 19:33:30,029] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000216.json
# [2017-10-14 19:33:30,181] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000343.json
# [2017-10-14 19:33:30,367] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000512.json
# [2017-10-14 19:33:30,630] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video000729.json

# %%
print "Final Q-Table Values"
print Q
# Out:
# Final Q-Table Values
# [[-0.06562736 -0.2172418  -0.21299943 -0.18396484]
#  [-0.35475452 -0.26999386 -0.28266196 -0.09310874]
#  [-0.22861668 -0.24796408 -0.22819964 -0.09412785]
#  [-0.3223585  -0.47102408 -0.33268901 -0.10316806]
#  [-0.07129505 -0.38965693 -0.38017464 -0.66170275]
#  [ 0.          0.          0.          0.        ]
#  [-0.53089994 -0.70582886 -0.60535399 -0.67000791]
#  [ 0.          0.          0.          0.        ]
#  [-0.39727319 -0.4471358  -0.36584854 -0.0801372 ]
#  [-0.31468547 -0.09299195 -0.51329902 -0.44445354]
#  [-0.16771133 -0.36123664 -0.40420174 -0.45998999]
#  [ 0.          0.          0.          0.        ]
#  [ 0.          0.          0.          0.        ]
#  [-0.32732886 -0.32807867 -0.05698809 -0.48861646]
#  [-0.15692418 -0.13429025 -0.16110411 -0.15658517]
#  [ 0.          0.          0.          0.        ]]

# %%
s = env.reset()
d=False
n=0
while d==False:
    n+=1
    a = np.argmax(Q[s,:])
    s,r,d,x = env.step(a)
    #print("%s %s %s %s"%(s,r,d,x))
    env.render()
print n
# Out:
# [2017-10-14 19:33:31,246] Starting new video recorder writing to C:\tmp\FrozenLake_01\openaigym.video.0.16148.video001000.json
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Up)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Right)
# SFFF
# FHFH
# FFFH
# HFFG
#   (Down)
# SFFF
# FHFH
# FFFH
# HFFG
# 67

# %%
env.close()
#gym.upload('/tmp/FrozenLake_01', api_key='sk_o9OoYpSkKamkW8MrKuHw')
# Out:
# [2017-10-14 19:33:31,427] Finished writing results. You can upload them to the scoreboard via gym.upload('C:\\tmp\\FrozenLake_01')

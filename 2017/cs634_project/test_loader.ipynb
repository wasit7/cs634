# %%
#http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02084071
import shutil
import requests
import uuid

for url in dogs:
    response = requests.get(url, stream=True)
    with open('dataset/dog/{}.jpg'.format(uuid.uuid4()), 'wb') as out_file:
        shutil.copyfileobj(response.raw, out_file)
    del response

# %%
import requests

# %%
url="http://www.image-net.org/api/text/imagenet.synset.geturls?wnid=n02084071"
response=requests.get(url, stream=True)

# %%
response.text.split()
# Out:
# [u'http://farm1.static.flickr.com/164/358144227_01e5544b79.jpg',
#  u'http://www.pantherkut.com/wp-content/uploads/2007/04/2.jpg',
#  u'http://farm3.static.flickr.com/2325/1891011832_cb5d5098c2.jpg',
#  u'http://farm1.static.flickr.com/1/2800688_afe83c164a.jpg',
#  u'http://farm1.static.flickr.com/46/151838410_88d0d8198b.jpg',
#  u'http://www.jameswilsonphotography.com/photogallery/photo3146/Dog.jpg',
#  u'http://farm1.static.flickr.com/147/421773683_7705c66f95.jpg',
#  u'http://farm1.static.flickr.com/48/146403300_0128782865.jpg',
#  u'http://static.flickr.com/5/7220886_ece3a7ecea.jpg',
#  u'http://www.mierdas.es/wp-content/uploads/2006/12/perro-con-dentadura.jpg',
#  u'http://farm2.static.flickr.com/1142/1273843380_424d34d58b.jpg',
#  u'http://farm2.static.flickr.com/1319/917422312_81f0dcce5b.jpg',
#  u'http://www.cosasdeperro.com/wp-content/uploads/2007/10/perro-muerto-exposicion.JPG',
#  u'http://farm1.static.flickr.com/173/406696834_c1e6e29d20.jpg',
# ...
